# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
dd = pd.read_excel('type1-and-type2-data-data-dictionary.xlsx')

# %%
dd
# Out:
#                         hashID  \
# 0                diagnosisType
# 1                   currentAge
# 2                 diagnosisAge
# 3      yearsLivingWithDiabetes
# 4                  basal.count
# 5                  bolus.count
# 6                    cbg.count
# 7            deviceEvent.count
# 8           pumpSettings.count
# 9                   smbg.count
# 10                upload.count
# 11                wizard.count
# 12        cbg.nUniqueDeviceIds
# 13      bolus.nUniqueDeviceIds
# 14       smbg.nUniqueDeviceIds
# 15         basal.nDaysWithData
# 16         bolus.nDaysWithData
# 17           cbg.nDaysWithData
# 18   deviceEvent.nDaysWithData
# 19  pumpSettings.nDaysWithData
# 20          smbg.nDaysWithData
# 21        upload.nDaysWithData
# 22        wizard.nDaysWithData
# 23           cgmSettings.count
# 24   cgmSettings.nDaysWithData
#
#                                              donor ID
# 0                                      type1 or type2
# ...

# %%
dd.loc[13, 'donor ID']
# Out:
# 'the number of unique devices the donor has for this data type'
